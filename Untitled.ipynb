# %%
# %matplotlib inline
from bs4 import BeautifulSoup
import requests

# %%
url = "https://physics.nist.gov/PhysRefData/Handbook/Tables/argontable2.htm"

# %%
r = requests.get(url)
d = r.text
soup = BeautifulSoup(d, "html5lib")

# %%
soup.find_all('table')
# Out:
# [<table border="0" cellpadding="0" cellspacing="0" width="100%">
#  <tbody><tr valign="bottom">
#  <td align="left"><img alt="NIST Physical Measurement Laboratory" border="0" height="68" src="/Images/But/nist-pl-black.gif" usemap="#NIST-PL" width="136"/></td>
#  <td align="center"><a href="../index.html"><img alt="Handbook of Basic Atomic Spectroscopic Data" border="0" height="54" src="../Images/HBannersm.jpg" title="Handbook of Basic Atomic Spectroscopic Data" width="438"/></a></td>
#  <td align="right"><img alt="" height="68" src="../Images/spacer.gif" width="136"/></td>
#  </tr></tbody></table>,
#  <table border="1" cellpadding="0" cellspacing="0"><tbody><tr><td>
#  <table bgcolor="#FFFFEE" border="0" cellpadding="0" cellspacing="0"><thead>
#  <tr bgcolor="#FFFFBB"><td> </td>
#  <th nowrap="" scope="col">Intensity</th><td> </td><td bgcolor="#000000"><img alt="" height="1" src="../Images/spacer.gif" width="1"/></td><td> </td>
# ...

# %%
import itertools

# %%
test = range(9)

# %%
# %%timeit
[[i for i in itertools.combinations(test, j)] for j in range(2, len(test))]
# Out:
# 32.9 µs ± 144 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
